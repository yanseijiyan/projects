# %% [markdown]
# THIS APP IS A CALCULATOR OF BMI

# %%
Heigth = float(input("Please enter your heigth(m)"))
Weigth = float(input("Please enter your weigth(kg)"))

BMI = Weigth / Heigth ** 2
print()
print("Your BMI value is: ", BMI)
# Out:
# Please enter your heigth(m)1.76
# Please enter your weigth(kg)56.1
#
# Your BMI value is:  18.110795454545457
